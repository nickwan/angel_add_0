# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.around(np.random.uniform(low=0, high=10, size=(50,4)), decimals=1), columns=list('ABCD'))

# %%
df
# Out:
#       A    B    C    D
# 0   8.6  2.5  4.2  7.9
# 1   0.9  0.2  1.1  3.8
# 2   5.7  8.3  6.9  1.2
# 3   8.3  1.4  7.6  8.6
# 4   5.8  0.2  1.4  1.3
# 5   0.2  6.6  8.0  0.6
# 6   5.1  7.1  4.7  9.3
# 7   1.8  1.9  2.7  1.3
# 8   5.3  8.3  0.4  2.0
# 9   2.0  2.4  8.3  5.7
# 10  5.0  0.7  6.3  0.1
# 11  4.5  7.9  8.7  0.1
# 12  1.9  1.1  4.4  7.7
# 13  5.1  6.2  3.3  9.2
# 14  7.0  3.9  5.9  6.8
# 15  1.9  6.2  9.0  0.4
# 16  7.3  9.7  6.5  6.0
# 17  6.7  2.6  5.3  8.0
# 18  6.9  2.9  4.0  9.6
# 19  6.9  1.6  4.8  6.4
# 20  0.2  7.1  7.3  3.1
# 21  3.5  5.8  1.4  4.9
# 22  0.2  4.6  6.6  2.8
# 23  6.1  3.0  6.7  3.7
# 24  4.6  2.4  7.2  0.7
# 25  7.5  9.7  9.1  8.1
# 26  7.4  8.6  0.9  1.9
# 27  2.3  9.6  1.0  8.5
# 28  0.2  1.7  7.6  3.0
# 29  4.9  8.1  2.6  7.3
# 30  1.5  2.7  7.3  0.2
# 31  2.5  0.4  7.6  3.4
# 32  0.3  9.8  9.1  9.0
# 33  4.2  4.1  1.5  1.9
# 34  5.5  9.9  0.0  6.9
# 35  3.1  5.5  3.4  1.6
# 36  2.8  3.7  7.6  9.5
# 37  7.9  1.2  2.7  4.6
# 38  3.7  8.8  9.9  3.5
# ...

# %%
df['A'].astype(str) + '0'
# Out:
# 0     8.60
# 1     0.90
# 2     5.70
# 3     8.30
# 4     5.80
# 5     0.20
# 6     5.10
# 7     1.80
# 8     5.30
# 9     2.00
# 10    5.00
# 11    4.50
# 12    1.90
# 13    5.10
# 14    7.00
# 15    1.90
# 16    7.30
# 17    6.70
# 18    6.90
# 19    6.90
# 20    0.20
# 21    3.50
# 22    0.20
# 23    6.10
# 24    4.60
# 25    7.50
# 26    7.40
# 27    2.30
# 28    0.20
# 29    4.90
# 30    1.50
# 31    2.50
# 32    0.30
# 33    4.20
# 34    5.50
# 35    3.10
# 36    2.80
# 37    7.90
# 38    3.70
# 39    0.90
# 40    5.70
# 41    3.10
# 42    4.10
# 43    3.40
# 44    0.60
# 45    0.40
# 46    1.70
# 47    7.90
# 48    1.60
# 49    9.10
# Name: A, dtype: object

# %%
df.astype(str) + '0'
# Out:
#        A     B     C     D
# 0   8.60  2.50  4.20  7.90
# 1   0.90  0.20  1.10  3.80
# 2   5.70  8.30  6.90  1.20
# 3   8.30  1.40  7.60  8.60
# 4   5.80  0.20  1.40  1.30
# 5   0.20  6.60  8.00  0.60
# 6   5.10  7.10  4.70  9.30
# 7   1.80  1.90  2.70  1.30
# 8   5.30  8.30  0.40  2.00
# 9   2.00  2.40  8.30  5.70
# 10  5.00  0.70  6.30  0.10
# 11  4.50  7.90  8.70  0.10
# 12  1.90  1.10  4.40  7.70
# 13  5.10  6.20  3.30  9.20
# 14  7.00  3.90  5.90  6.80
# 15  1.90  6.20  9.00  0.40
# 16  7.30  9.70  6.50  6.00
# 17  6.70  2.60  5.30  8.00
# 18  6.90  2.90  4.00  9.60
# 19  6.90  1.60  4.80  6.40
# 20  0.20  7.10  7.30  3.10
# 21  3.50  5.80  1.40  4.90
# 22  0.20  4.60  6.60  2.80
# 23  6.10  3.00  6.70  3.70
# 24  4.60  2.40  7.20  0.70
# 25  7.50  9.70  9.10  8.10
# 26  7.40  8.60  0.90  1.90
# 27  2.30  9.60  1.00  8.50
# 28  0.20  1.70  7.60  3.00
# 29  4.90  8.10  2.60  7.30
# 30  1.50  2.70  7.30  0.20
# 31  2.50  0.40  7.60  3.40
# 32  0.30  9.80  9.10  9.00
# ...
